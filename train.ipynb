# %%
# %pip install -Uq sagemaker==2.232.0 ultralytics==8.2.100 datasets==2.18.0
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import Dataset
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/ec2-user/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fqm5Enl2aSi9tTuX0yyV")
project = rf.workspace("qpj").project("pcb-defect-djz4r-uld1q")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 27.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 34.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 2.15.0 requires packaging>=22.0, but you have packaging 21.3 which is incompatible.
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pcb-defect-1 in yolov8:: 100%|██████████| 1398/1398 [00:00<00:00, 2137.91it/s]

# %%
from IPython.display import display, Image

# %%
# %ls
# Out:
# lost+found/  pcb-defect-1/  Untitled.ipynb

# %%
# 放弃，国内下载不下来 https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt，手动下载放目录
# !yolo task=detect mode=train model=/home/ec2-user/SageMaker/yolov8s.pt data=/home/ec2-user/SageMaker/pcb-defect-1/data.yaml epochs=150 imgsz=800 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.100 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.100 🚀 Python-3.10.14 torch-2.2.2 CUDA:0 (Tesla T4, 14918MiB)
# ...
